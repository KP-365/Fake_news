# %% [markdown]
# <a href="https://colab.research.google.com/github/KP-365/Fake_news/blob/main/eval_escalation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repository when needed, then install its dependencies (including ddgs).
import os
from pathlib import Path

if Path("Fake_news").is_dir():
    os.chdir("Fake_news")
    # !git pull
elif not Path("predict.py").exists():
    # !git clone https://github.com/KP-365/Fake_news
    os.chdir("Fake_news")
else:
    # !git pull

# !python3 -m pip uninstall -y torchao
# !python3 -m pip install -q -r requirements.txt torchvision
import torch, torchvision; print(f"Torch {torch.__version__}; torchvision {torchvision.__version__}; CUDA available: {torch.cuda.is_available()}")
# !git log --oneline -1
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 457 bytes | 228.00 KiB/s, done.
# From https://github.com/KP-365/Fake_news
#    d8a74de..a38ca16  main       -> origin/main
# Updating d8a74de..a38ca16
# Fast-forward
#  eval_escalation.ipynb | 10 ++++++++--
#  1 file changed, 8 insertions(+), 2 deletions(-)
# WARNING: Skipping torchao as it is not installed.
# Torch 2.12.0+cu130; torchvision 0.27.0+cu130; CUDA available: True
# a38ca16 (HEAD -> main, origin/main, origin/HEAD) Make Colab escalation setup idempotent

# %%
# Run MC Dropout selection and NLI escalation; results are also saved as CSV.
# %run evaluation/eval_escalation.py
# Out:
# Using Colab cache for faster access to the 'fake-news-classification' dataset.
# Loaded 9,398 held-out WELFake test articles
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# classifier.out_proj.bias        | MISSING    |
# classifier.dense.weight         | MISSING    |
# classifier.dense.bias           | MISSING    |
# classifier.out_proj.weight      | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Classifier device: cuda
# MC Dropout: 320/9,398 articles
# MC Dropout: 640/9,398 articles
# MC Dropout: 960/9,398 articles
# MC Dropout: 1,280/9,398 articles
# MC Dropout: 1,600/9,398 articles
# MC Dropout: 1,920/9,398 articles
# MC Dropout: 2,240/9,398 articles
# MC Dropout: 2,560/9,398 articles
# MC Dropout: 2,880/9,398 articles
# MC Dropout: 3,200/9,398 articles
# MC Dropout: 3,520/9,398 articles
# MC Dropout: 3,840/9,398 articles
# MC Dropout: 4,160/9,398 articles
# MC Dropout: 4,480/9,398 articles
# MC Dropout: 4,800/9,398 articles
# MC Dropout: 5,120/9,398 articles
# MC Dropout: 5,440/9,398 articles
# MC Dropout: 5,760/9,398 articles
# MC Dropout: 6,080/9,398 articles
# MC Dropout: 6,400/9,398 articles
# MC Dropout: 6,720/9,398 articles
# MC Dropout: 7,040/9,398 articles
# MC Dropout: 7,360/9,398 articles
# MC Dropout: 7,680/9,398 articles
# MC Dropout: 8,000/9,398 articles
# MC Dropout: 8,320/9,398 articles
# MC Dropout: 8,640/9,398 articles
# MC Dropout: 8,960/9,398 articles
# MC Dropout: 9,280/9,398 articles
# MC Dropout: 9,398/9,398 articles
# config.json:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# spm.model: reconstructing file:   0%|          |  0.00B / 2.46MB
# spm.model: downloading bytes:           |  0.00B
# tokenizer.json:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  369MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# DebertaV2ForSequenceClassification LOAD REPORT from: MoritzLaurer/DeBERTa-v3-base-mnli-fever-anli
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# deberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Verified 1/100: supported
# Verified 2/100: supported
# Verified 3/100: supported
# Verified 4/100: supported
# Verified 5/100: supported
# Verified 6/100: refuted
# Verified 7/100: supported
# Verified 8/100: insufficient
# Verified 9/100: refuted
# Verified 10/100: supported
# Verified 11/100: refuted
# Verified 12/100: refuted
# Verified 13/100: supported
# Verified 14/100: refuted
# Verified 15/100: supported
# Verified 16/100: refuted
# Verified 17/100: insufficient
# Verified 18/100: refuted
# Verified 19/100: insufficient
# Verified 20/100: insufficient
# Verified 21/100: refuted
# Verified 22/100: insufficient
# Verified 23/100: insufficient
# Verified 24/100: supported
# Verified 25/100: insufficient
# Verified 26/100: refuted
# Verified 27/100: supported
# Verified 28/100: supported
# Verified 29/100: insufficient
# Verified 30/100: insufficient
# Verified 31/100: refuted
# Verified 32/100: supported
# Verified 33/100: supported
# Verified 34/100: insufficient
# Verified 35/100: refuted
# Verified 36/100: supported
# Verified 37/100: refuted
# Verified 38/100: supported
# Verified 39/100: refuted
# Verified 40/100: refuted
# Verified 41/100: refuted
# Verified 42/100: supported
# Verified 43/100: refuted
# Verified 44/100: insufficient
# Verified 45/100: supported
# Verified 46/100: insufficient
# Verified 47/100: refuted
# Verified 48/100: refuted
# Verified 49/100: insufficient
# Verified 50/100: insufficient
# Verified 51/100: supported
# Verified 52/100: insufficient
# Verified 53/100: refuted
# Verified 54/100: refuted
# Verified 55/100: supported
# Verified 56/100: supported
# Verified 57/100: supported
# Verified 58/100: insufficient
# Verified 59/100: supported
# Verified 60/100: insufficient
# Verified 61/100: refuted
# Verified 62/100: refuted
# Verified 63/100: refuted
# Verified 64/100: supported
# Verified 65/100: refuted
# Verified 66/100: insufficient
# Verified 67/100: supported
# Verified 68/100: supported
# Verified 69/100: insufficient
# Verified 70/100: supported
# Verified 71/100: supported
# Verified 72/100: supported
# Verified 73/100: supported
# Verified 74/100: supported
# Verified 75/100: insufficient
# Verified 76/100: supported
# Verified 77/100: insufficient
# Verified 78/100: refuted
# Verified 79/100: refuted
# Verified 80/100: refuted
# Verified 81/100: supported
# Verified 82/100: refuted
# Verified 83/100: refuted
# Verified 84/100: supported
# Verified 85/100: supported
# Verified 86/100: supported
# Verified 87/100: insufficient
# Verified 88/100: supported
# Verified 89/100: supported
# Verified 90/100: supported
# Verified 91/100: supported
# Verified 92/100: supported
# Verified 93/100: refuted
# Verified 94/100: insufficient
# Verified 95/100: supported
# Verified 96/100: refuted
# Verified 97/100: insufficient
# Verified 98/100: insufficient
# Verified 99/100: insufficient
# Verified 100/100: refuted
#
# Saved 100 rows to /content/Fake_news/evaluation/escalation_results.csv
# Classifier-only accuracy: 0.7600
# Classifier + NLI accuracy: 0.6400
# Verdict distribution:
#   supported: 42
#   refuted: 32
#   insufficient: 26
